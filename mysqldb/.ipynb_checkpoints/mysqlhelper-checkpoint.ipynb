# %%
import mysql.connector

class dbhelper:
    def __init__(self, host, user, passwd, database):
        self.mydb = mysql.connector.connect(
          host=host,
          user=user,
          passwd=passwd,
          database=database,
          auth_plugin='mysql_native_password'
        )

    def addSingleData(self, sql, val):
        mycursor = self.mydb.cursor()
        mycursor.execute(sql, val)
        self.mydb.commit()
        
    def addData(self, sql, val):
        mycursor = self.mydb.cursor()
        mycursor.executemany(sql, val)
        self.mydb.commit()
    
    def getData(self, sql, val = None, dic = False):
        if val != None:
            adr = (val, )
            mycursor = self.mydb.cursor(dictionary=dic)
            mycursor.execute(sql, adr)
            myresult = mycursor.fetchall()
            return myresult
        else:
            mycursor = self.mydb.cursor(dictionary=dic)
            mycursor.execute(sql)
            myresult = mycursor.fetchall()
            return myresult
        
    def close(self):
        self.mydb.cursor().close()
        self.mydb.close()


#val = [(1, 1, 2, 3, 4, 5, 6, 7, 100, 10, 2, 10, "2012-10-03")]
    
#addData(val)

# %%
dbhelper('127.0.0.1', 'yso1983', '123456', 'lotto').getData( "SELECT * FROM lotto_info LIMIT 10;", None, True)
# Out:
# [{'drwNo': 1,
#   'drwtNo1': 10,
#   'drwtNo2': 23,
#   'drwtNo3': 29,
#   'drwtNo4': 33,
#   'drwtNo5': 37,
#   'drwtNo6': 40,
#   'bnusNo': 16,
#   'totSellamnt': 3681782000,
#   'firstAccumamnt': 863604600,
#   'firstPrzwnerCo': 0,
#   'firstWinamnt': 0,
#   'drwNoDate': datetime.date(2002, 12, 7)},
#  {'drwNo': 2,
#   'drwtNo1': 9,
#   'drwtNo2': 13,
#   'drwtNo3': 21,
#   'drwtNo4': 25,
#   'drwtNo5': 32,
#   'drwtNo6': 42,
#   'bnusNo': 2,
#   'totSellamnt': 4904274000,
#   'firstAccumamnt': 0,
#   'firstPrzwnerCo': 1,
#   'firstWinamnt': 2002006800,
#   'drwNoDate': datetime.date(2002, 12, 14)},
#  {'drwNo': 3,
#   'drwtNo1': 11,
#   'drwtNo2': 16,
#   'drwtNo3': 19,
#   'drwtNo4': 21,
#   'drwtNo5': 27,
#   'drwtNo6': 31,
#   'bnusNo': 30,
#   'totSellamnt': 4729342000,
#   'firstAccumamnt': 0,
#   'firstPrzwnerCo': 1,
#   'firstWinamnt': 2000000000,
#   'drwNoDate': datetime.date(2002, 12, 21)},
#  {'drwNo': 4,
#   'drwtNo1': 14,
#   'drwtNo2': 27,
#   'drwtNo3': 30,
#   'drwtNo4': 31,
#   'drwtNo5': 40,
#   'drwtNo6': 42,
#   'bnusNo': 2,
#   'totSellamnt': 5271464000,
#   'firstAccumamnt': 1267147200,
#   'firstPrzwnerCo': 0,
#   'firstWinamnt': 0,
#   'drwNoDate': datetime.date(2002, 12, 28)},
#  {'drwNo': 5,
#   'drwtNo1': 16,
#   'drwtNo2': 24,
#   'drwtNo3': 29,
#   'drwtNo4': 40,
#   'drwtNo5': 41,
#   'drwtNo6': 42,
#   'bnusNo': 3,
#   'totSellamnt': 6277102000,
#   'firstAccumamnt': 3041094900,
#   'firstPrzwnerCo': 0,
#   'firstWinamnt': 0,
#   'drwNoDate': datetime.date(2003, 1, 4)},
#  {'drwNo': 6,
#   'drwtNo1': 14,
#   'drwtNo2': 15,
#   'drwtNo3': 26,
#   'drwtNo4': 27,
#   'drwtNo5': 40,
#   'drwtNo6': 42,
#   'bnusNo': 34,
#   'totSellamnt': 15305356000,
#   'firstAccumamnt': 0,
#   'firstPrzwnerCo': 1,
#   'firstWinamnt': 6574451700,
#   'drwNoDate': datetime.date(2003, 1, 11)},
#  {'drwNo': 7,
#   'drwtNo1': 2,
#   'drwtNo2': 9,
#   'drwtNo3': 16,
#   'drwtNo4': 25,
#   'drwtNo5': 26,
#   'drwtNo6': 40,
#   'bnusNo': 42,
#   'totSellamnt': 12794890000,
#   'firstAccumamnt': 2600913000,
#   'firstPrzwnerCo': 0,
#   'firstWinamnt': 0,
#   'drwNoDate': datetime.date(2003, 1, 18)},
#  {'drwNo': 8,
#   'drwtNo1': 8,
#   'drwtNo2': 19,
#   'drwtNo3': 25,
#   'drwtNo4': 34,
#   'drwtNo5': 37,
#   'drwtNo6': 39,
#   'bnusNo': 9,
#   'totSellamnt': 20751450000,
#   'firstAccumamnt': 7336896000,
#   'firstPrzwnerCo': 0,
#   'firstWinamnt': 0,
#   'drwNoDate': datetime.date(2003, 1, 25)},
#  {'drwNo': 9,
#   'drwtNo1': 2,
#   'drwtNo2': 4,
#   'drwtNo3': 16,
#   'drwtNo4': 17,
#   'drwtNo5': 36,
#   'drwtNo6': 39,
#   'bnusNo': 14,
#   'totSellamnt': 73624020000,
#   'firstAccumamnt': 25803852000,
#   'firstPrzwnerCo': 0,
#   'firstWinamnt': 0,
#   'drwNoDate': datetime.date(2003, 2, 1)},
#  {'drwNo': 10,
#   'drwtNo1': 9,
#   'drwtNo2': 25,
#   'drwtNo3': 30,
#   'drwtNo4': 33,
#   'drwtNo5': 41,
#   'drwtNo6': 44,
#   'bnusNo': 6,
#   'totSellamnt': 260856392000,
#   'firstAccumamnt': 0,
#   'firstPrzwnerCo': 13,
#   'firstWinamnt': 6430437900,
#   'drwNoDate': datetime.date(2003, 2, 8)}]

# %%
dbhelper('127.0.0.1', 'yso1983', '123456', 'lotto').close()
